# %% [markdown]
# <a href="https://colab.research.google.com/github/anushkarajora11/VisiTrack/blob/Week_1/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 1 :ML assignment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('data.csv')
print(data.head())
# Assuming last column is the target
X = data.drop('Price' , axis =1)
Y = data['Price']
print(X.head())
print(Y.head())
# Out:
#    ID  Square_Feet  Num_Bedrooms  ...  Location_Score  Distance_to_Center  Price
# 0   1   143.635030           1.0  ...        8.297631            5.935734   6021
# 1   2   287.678577           1.0  ...        6.061466           10.827392   5914
# 2   3   232.998485           1.0  ...        2.911442            6.904599   4645
# 3   4   199.664621           5.0  ...        2.070949            8.284019   5831
# 4   5    89.004660           4.0  ...        1.523278           14.648277   6199
#
# [5 rows x 12 columns]
#    ID  Square_Feet  ...  Location_Score  Distance_to_Center
# 0   1   143.635030  ...        8.297631            5.935734
# 1   2   287.678577  ...        6.061466           10.827392
# 2   3   232.998485  ...        2.911442            6.904599
# 3   4   199.664621  ...        2.070949            8.284019
# 4   5    89.004660  ...        1.523278           14.648277
#
# [5 rows x 11 columns]
# 0    6021
# 1    5914
# 2    4645
# 3    5831
# 4    6199
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("data.csv")
data.head()

data = data.drop(columns=['ID'])

print(data.info())

print(data.describe())

plt.figure(figsize=(10, 8))
sns.heatmap(data.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(data['Price'], kde=True)
plt.title("Price Distribution")
plt.show()

X = data.drop(columns=['Price']).values
y = data['Price'].values.reshape(-1, 1)

X_b = np.hstack([np.ones((X.shape[0], 1)), X])

beta = np.linalg.inv(X_b.T @ X_b) @ X_b.T @ y
print("Coefficients (including intercept):\n", beta)

y_pred = X_b @ beta

MSE = np.mean((y - y_pred) ** 2)
print("Mean Squared Error (MSE):", MSE)

RSS = np.sum((y - y_pred) ** 2)
print("Residual Sum of Squares (RSS):", RSS)
plt.figure(figsize=(8, 6))
plt.scatter(y, y_pred, color='blue', edgecolor='k')
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--')
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted Price")
plt.grid(True)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Square_Feet         495 non-null    float64
#  1   Num_Bedrooms        494 non-null    float64
#  2   Num_Bathrooms       499 non-null    float64
#  3   Num_Floors          497 non-null    float64
#  4   Year_Built          498 non-null    float64
#  5   Has_Garden          494 non-null    float64
#  6   Has_Pool            499 non-null    float64
#  7   Garage_Size         496 non-null    float64
#  8   Location_Score      499 non-null    float64
#  9   Distance_to_Center  499 non-null    float64
#  10  Price               500 non-null    int64
# dtypes: float64(10), int64(1)
# memory usage: 43.1 KB
# None
#        Square_Feet  Num_Bedrooms  ...  Distance_to_Center        Price
# count   495.000000    494.000000  ...          499.000000   500.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

selected_columns = data.drop(columns=['Price']).columns
plt.figure(figsize=(12, 10))
sns.pairplot(data[selected_columns])
plt.suptitle("Matrix Plot of Features", y=1.02)
plt.show()
sns.pairplot(data, vars=data.columns, corner=True)
plt.suptitle("Pairwise Matrix Plot Including Price", y=1.02)
plt.show()
